# %% [markdown]
# <a href="https://colab.research.google.com/github/minmings111/practice-numpy/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# and, nand, or 게이트는 모두 같은 구조의 퍼센트론

# and 게이트
def AND(x1, x2):
  w1, w2, theta = 0.5, 0.5, 0.7
  tmp = x1*w1 + x2*w2

  if tmp <= theta:
    return 0
  elif tmp > theta:
    return 1

# %%
print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %%
x = np.array([0, 1]) #입력
w = np.array([0.5, 0.5]) # 가중치
b = -0.7 # bias

print(w*x)
print(np.sum(w*x))
print(np.sum(w*x)+b) #대략 -0.2(부동소수점 수에 의한 연산 오차)
# Out:
# [0.  0.5]
# 0.5
# -0.19999999999999996

# %%
def AND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.7 # bias

  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else :
    return 1

# %%
print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %%
# nand 게이트
def NAND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([-0.5, -0.5]) # and와는 가중치만 다름
  b = 0.7

  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
print(NAND(0, 0))
print(NAND(1, 0))
print(NAND(0, 1))
print(NAND(1, 1))
# Out:
# 1
# 1
# 1
# 0

# %%
# or 게이트
def OR(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.2

  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
print(OR(0, 0))
print(OR(1, 0))
print(OR(0, 1))
print(OR(1, 1))
# Out:
# 0
# 1
# 1
# 1

# %%
# 다층 퍼셉트론
# xor은 비선형 영역이라서 단층 퍼셉트론으로는 표현할 수 없고,
# 다층 퍼셉트론으로 표현할 수 있음.

def XOR(x1, x2):
  s1 = NAND(x1, x2)
  s2 = OR(x1, x2)
  y = AND(s1, s2)
  return y

# %%
print(XOR(0, 0))
print(XOR(1, 0))
print(XOR(0, 1))
print(XOR(1, 1))
# Out:
# 0
# 1
# 1
# 0
